# %% [markdown]
# ## Customer Fraud Detector

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline as SklearnPipeline

from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    confusion_matrix,
    classification_report,
    roc_curve,
    precision_recall_curve
)

import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("customer_analytics_dataset.csv")

# %%
data.shape
# Out:
# (5000, 13)

# %%
data.head()
# Out:
#    age  gender    country  avg_order_value  total_orders  is_fraudulent  \
# 0   30  Female     Brazil           101.08             8              1
# 1   53  Female        USA            90.39            10              0
# 2   73    Male  Australia            83.28             6              0
# 3   30   Other      Japan           109.90             9              1
# 4   29  Female     Canada           269.38            16              0
#
#   preferred_category  email_open_rate  loyalty_score  churn_risk  \
# 0             Beauty        25.600000             50        0.20
# 1        Electronics        12.300000             37        0.34
# 2             Sports        50.714842             65        0.05
# 3        Electronics        42.900000             93        0.19
# 4            Fashion         5.300000             79        0.15
#
#    days_since_last_purchase  customer_tenure_days  estimated_total_spend
# 0                         0                -19879                 808.64
# 1                         0                -19772                 903.90
# 2                         0                -19829                 499.68
# 3                         0                -18451                 989.10
# 4                         0                -20187                4310.08

# %%
data.columns.tolist()
# Out:
# ['age',
#  'gender',
#  'country',
#  'avg_order_value',
#  'total_orders',
#  'is_fraudulent',
#  'preferred_category',
#  'email_open_rate',
#  'loyalty_score',
#  'churn_risk',
#  'days_since_last_purchase',
#  'customer_tenure_days',
#  'estimated_total_spend']

# %%
data.dtypes
# Out:
# age                           int64
# gender                       object
# country                      object
# avg_order_value             float64
# total_orders                  int64
# is_fraudulent                 int64
# preferred_category           object
# email_open_rate             float64
# loyalty_score                 int64
# churn_risk                  float64
# days_since_last_purchase      int64
# customer_tenure_days          int64
# estimated_total_spend       float64
# dtype: object

# %%
data.isnull().sum()
# Out:
# age                         0
# gender                      0
# country                     0
# avg_order_value             0
# total_orders                0
# is_fraudulent               0
# preferred_category          0
# email_open_rate             0
# loyalty_score               0
# churn_risk                  0
# days_since_last_purchase    0
# customer_tenure_days        0
# estimated_total_spend       0
# dtype: int64

# %%
# data = data.fillna(data.mean(numeric_only=True))
SimpleImputer(strategy="median")
# Out:
# SimpleImputer(strategy='median')

# %%
data.isnull().sum()
# Out:
# age                         0
# gender                      0
# country                     0
# avg_order_value             0
# total_orders                0
# is_fraudulent               0
# preferred_category          0
# email_open_rate             0
# loyalty_score               0
# churn_risk                  0
# days_since_last_purchase    0
# customer_tenure_days        0
# estimated_total_spend       0
# dtype: int64

# %%
target = "is_fraudulent"

print(data[target].value_counts())
print("\nPercentage:")
print(data[target].value_counts(normalize=True) * 100)
# Out:
# is_fraudulent
# 0    4871
# 1     129
# Name: count, dtype: int64
#
# Percentage:
# is_fraudulent
# 0    97.42
# 1     2.58
# Name: proportion, dtype: float64

# %%
sns.countplot(x=target, data=data)
plt.title("Fraudulent vs Non-Fraudulent Records")
plt.xlabel("Fraudulent")
plt.ylabel("Count")
plt.show()

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.describe()
# Out:
#                age  avg_order_value  total_orders  is_fraudulent  \
# count  5000.000000      5000.000000   5000.000000    5000.000000
# mean     48.163200       108.442857     10.027000       0.025800
# std      17.880797        67.511360      3.163838       0.158554
# min      18.000000        10.660000      0.000000       0.000000
# 25%      33.000000        59.560000      8.000000       0.000000
# 50%      48.000000        97.405000     10.000000       0.000000
# 75%      64.000000       138.807500     12.000000       0.000000
# max      79.000000       555.460000     23.000000       1.000000
#
#        email_open_rate  loyalty_score   churn_risk  days_since_last_purchase  \
# count      5000.000000    5000.000000  5000.000000                    5000.0
# mean         50.714842      50.039400     0.284484                       0.0
# std          28.361761      28.832151     0.159690                       0.0
# min           0.000000       1.000000     0.000000                       0.0
# 25%          26.400000      25.000000     0.160000                       0.0
# 50%          50.714842      50.000000     0.260000                       0.0
# 75%          75.300000      75.000000     0.390000                       0.0
# max         100.000000      99.000000     0.900000                       0.0
#
#        customer_tenure_days  estimated_total_spend
# count           5000.000000            5000.000000
# mean          -19359.417400            1093.378821
# std              529.887983             804.458264
# min           -20267.000000               0.000000
# 25%           -19824.000000             542.214284
# 50%           -19368.000000             901.680000
# 75%           -18890.000000            1409.757139
# max           -18442.000000            8887.360000

# %%
for col in data.columns:
    print(f"{col}: {data[col].nunique()} unique values")
# Out:
# age: 62 unique values
# gender: 3 unique values
# country: 10 unique values
# avg_order_value: 4222 unique values
# total_orders: 24 unique values
# is_fraudulent: 2 unique values
# preferred_category: 5 unique values
# email_open_rate: 990 unique values
# loyalty_score: 99 unique values
# churn_risk: 88 unique values
# days_since_last_purchase: 1 unique values
# customer_tenure_days: 1701 unique values
# estimated_total_spend: 4641 unique values

# %%
numeric_cols = data.select_dtypes(include=np.number).columns.tolist()
numeric_cols.remove(target)
print(numeric_cols)
# Out:
# ['age', 'avg_order_value', 'total_orders', 'email_open_rate', 'loyalty_score', 'churn_risk', 'days_since_last_purchase', 'customer_tenure_days', 'estimated_total_spend']

# %%
data[numeric_cols].hist(
    figsize=(13, 10),
    bins=30
)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))

correlation = data[numeric_cols + [target]].corr()

sns.heatmap(
    correlation,
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.xticks(rotation=45)
plt.title("Correlation Heatmap")
plt.show()

# %%
data["last_purchase"] = pd.to_datetime(
    data["last_purchase"],
    errors="coerce"
)

data["customer_since"] = pd.to_datetime(
    data["customer_since"],
    errors="coerce"
)

reference_date = data["last_purchase"].max()

data["days_since_last_purchase"] = (
    reference_date - data["last_purchase"]
).dt.days

data["customer_tenure_days"] = (
    data["last_purchase"] - data["customer_since"]
).dt.days

data["estimated_total_spend"] = (
    data["avg_order_value"] * data["total_orders"]
)

data = data.drop(
    columns=[
        "customer_id",
        # "last_purchase",
        "customer_since"
    ]
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
# --> 167 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
# --> 196 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7088 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7096 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'last_purchase'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[210], line 2
#       1 data["last_purchase"] = pd.to_datetime(
# ----> 2     data["last_purchase"],
#       3     errors="coerce"
#       4 )
#       5
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4109
#    4110         if is_single_key:
#    4111             if self.columns.nlevels > 1:
#    4112                 return self._getitem_multilevel(key)
# -> 4113             indexer = self.columns.get_loc(key)
#    4114             if is_integer(indexer):
#    4115                 indexer = [indexer]
#    4116         else:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'last_purchase'

# %%
X = data.drop(columns=[target])
y = data[target].astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.30,
    random_state=42,
    stratify=y
)
print("Training:")
print(y_train.value_counts())

print("\nTesting:")
print(y_test.value_counts())
# Out:
# Training:
# is_fraudulent
# 0    3410
# 1      90
# Name: count, dtype: int64
#
# Testing:
# is_fraudulent
# 0    1461
# 1      39
# Name: count, dtype: int64

# %%
numeric_features = X_train.select_dtypes(
    include=["int64", "float64"]
).columns.tolist()

categorical_features = X_train.select_dtypes(
    include=["object", "category", "bool"]
).columns.tolist()

print("Numerical Features:")
print(numeric_features)

print("\nCategorical Features:")
print(categorical_features)
# Out:
# Numerical Features:
# ['age', 'avg_order_value', 'total_orders', 'email_open_rate', 'loyalty_score', 'churn_risk', 'days_since_last_purchase', 'customer_tenure_days', 'estimated_total_spend']
#
# Categorical Features:
# ['gender', 'country', 'preferred_category']

# %%
numeric_transformer = SklearnPipeline(
    steps=[
        ("imputer", SimpleImputer(strategy="median")),
        ("scaler", StandardScaler())
    ]
)

categorical_transformer = SklearnPipeline(
    steps=[
        ("imputer", SimpleImputer(strategy="most_frequent")),
        (
            "encoder",
            OneHotEncoder(
                handle_unknown="ignore",
                sparse_output=False
            )
        )
    ]
)

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numeric_features),
        ("cat", categorical_transformer, categorical_features)
    ]
)

# %%
print("Before SMOTE:")
print(y_train.value_counts())

X_train_processed = preprocessor.fit_transform(X_train)

smote = SMOTE(random_state=42)

X_resampled, y_resampled = smote.fit_resample(
    X_train_processed,
    y_train
)

print("\nAfter SMOTE:")
print(pd.Series(y_resampled).value_counts())
# Out:
# Before SMOTE:
# is_fraudulent
# 0    3410
# 1      90
# Name: count, dtype: int64
#
# After SMOTE:
# is_fraudulent
# 0    3410
# 1    3410
# Name: count, dtype: int64

# %%
# smote = SMOTE(
#     random_state=42
# )

# %%
dt_model = DecisionTreeClassifier(
    random_state=42,
    max_depth=10,
    min_samples_split=10,
    class_weight=None
)
dt_model
# Out:
# DecisionTreeClassifier(max_depth=10, min_samples_split=10, random_state=42)

# %%
dt_pipeline = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ("smote", SMOTE(random_state=42)),
        ("model", dt_model)
    ]
)
dt_pipeline
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['age', 'avg_order_value',
#                                                    'total_orders',
#                                                    'email_open_rate',
#                                                    'loyalty_score',
#                                                    'churn_risk',
#                                                    'days_since_last_purchase',
#                                                    'customer_tenure_days',
#                                                    'estimated_total_spend']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['gender', 'country',
#                                                    'preferred_category'])])),
#                 ('smote', SMOTE(random_state=42)),
#                 ('model',
#                  DecisionTreeClassifier(max_depth=10, min_samples_split=10,
#                                         random_state=42))])

# %%
dt_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['age', 'avg_order_value',
#                                                    'total_orders',
#                                                    'email_open_rate',
#                                                    'loyalty_score',
#                                                    'churn_risk',
#                                                    'days_since_last_purchase',
#                                                    'customer_tenure_days',
#                                                    'estimated_total_spend']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['gender', 'country',
#                                                    'preferred_category'])])),
#                 ('smote', SMOTE(random_state=42)),
#                 ('model',
#                  DecisionTreeClassifier(max_depth=10, min_samples_split=10,
#                                         random_state=42))])

# %%
rf_model = RandomForestClassifier(
    n_estimators=300,
    max_depth=15,
    min_samples_split=5,
    random_state=42,
    n_jobs=-1
)
rf_model
# Out:
# RandomForestClassifier(max_depth=15, min_samples_split=5, n_estimators=300,
#                        n_jobs=-1, random_state=42)

# %%
rf_pipeline = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ("smote", SMOTE(random_state=42)),
        ("model", rf_model)
    ]
)
rf_pipeline
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['age', 'avg_order_value',
#                                                    'total_orders',
#                                                    'email_open_rate',
#                                                    'loyalty_score',
#                                                    'churn_risk',
#                                                    'days_since_last_purchase',
#                                                    'customer_tenure_days',
#                                                    'estimated_total_spend']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['gender', 'country',
#                                                    'preferred_category'])])),
#                 ('smote', SMOTE(random_state=42)),
#                 ('model',
#                  RandomForestClassifier(max_depth=15, min_samples_split=5,
#                                         n_estimators=300, n_jobs=-1,
#                                         random_state=42))])

# %%
rf_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['age', 'avg_order_value',
#                                                    'total_orders',
#                                                    'email_open_rate',
#                                                    'loyalty_score',
#                                                    'churn_risk',
#                                                    'days_since_last_purchase',
#                                                    'customer_tenure_days',
#                                                    'estimated_total_spend']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['gender', 'country',
#                                                    'preferred_category'])])),
#                 ('smote', SMOTE(random_state=42)),
#                 ('model',
#                  RandomForestClassifier(max_depth=15, min_samples_split=5,
#                                         n_estimators=300, n_jobs=-1,
#                                         random_state=42))])

# %%
xgb_model = XGBClassifier(
    n_estimators=300,
    max_depth=6,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    objective="binary:logistic",
    eval_metric="logloss",
    random_state=42,
    n_jobs=-1
)
xgb_model
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=True, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=300, n_jobs=-1,
#               num_parallel_tree=None, ...)

# %%
xgb_pipeline = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ("smote", SMOTE(random_state=42)),
        ("model", xgb_model)
    ]
)
xgb_pipeline
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['age', 'avg_order_value',
#                                                    'total_orders',
#                                                    'email_open_rate',
#                                                    'loyalty_score',
#                                                    'churn_risk',
#                                                    'days_since_last_purchase',
#                                                    'customer_tenure_days',
#                                                    'estimated_total_spend']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('...
#                                feature_types=None, feature_weights=None,
#                                gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=0.05,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=6, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=300, n_jobs=-1,
#                                num_parallel_tree=None, ...))])

# %%
xgb_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['age', 'avg_order_value',
#                                                    'total_orders',
#                                                    'email_open_rate',
#                                                    'loyalty_score',
#                                                    'churn_risk',
#                                                    'days_since_last_purchase',
#                                                    'customer_tenure_days',
#                                                    'estimated_total_spend']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('...
#                                feature_types=None, feature_weights=None,
#                                gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=0.05,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=6, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=300, n_jobs=-1,
#                                num_parallel_tree=None, ...))])

# %%
models = {
    "Decision Tree": dt_pipeline,
    "Random Forest": rf_pipeline,
    "XGBoost": xgb_pipeline
}

# %%
for name, model in models.items():
    print(f"Training {name}...")
    model.fit(X_train, y_train)

print("Training completed.")
# Out:
# Training Decision Tree...
# Training Random Forest...
# Training XGBoost...
# Training completed.

# %%
predictions = {}

for name, model in models.items():
    y_pred = model.predict(X_test)
    y_prob = model.predict_proba(X_test)[:, 1]

    predictions[name] = {
        "y_pred": y_pred,
        "y_prob": y_prob
    }

# %%
results = []

for name, result in predictions.items():

    y_pred = result["y_pred"]
    y_prob = result["y_prob"]

    results.append({
        "Model": name,
        "Accuracy": accuracy_score(y_test, y_pred),
        "Precision": precision_score(y_test, y_pred, zero_division=0),
        "Recall": recall_score(y_test, y_pred, zero_division=0),
        "F1 Score": f1_score(y_test, y_pred, zero_division=0),
        "ROC-AUC": roc_auc_score(y_test, y_prob),
        "PR-AUC": average_precision_score(y_test, y_prob)
    })

results_df = pd.DataFrame(results)

results_df = results_df.sort_values(
    by="F1 Score",
    ascending=False
)

display(results_df)
# Out:
#            Model  Accuracy  Precision    Recall  F1 Score   ROC-AUC    PR-AUC
# 0  Decision Tree  0.907333   0.019231  0.051282  0.027972  0.574984  0.032382
# 1  Random Forest  0.972000   0.000000  0.000000  0.000000  0.601116  0.041413
# 2        XGBoost  0.974000   0.000000  0.000000  0.000000  0.630829  0.074802

# %%
best_model_name = results_df.iloc[0]["Model"]

best_model = models[best_model_name]

best_pred = predictions[best_model_name]["y_pred"]

cm = confusion_matrix(y_test, best_pred)

plt.figure(figsize=(6, 5))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["Not Fraud", "Fraud"],
    yticklabels=["Not Fraud", "Fraud"]
)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title(f"Confusion Matrix - {best_model_name}")

plt.show()

# %%
print(
    classification_report(
        y_test,
        best_pred,
        target_names=["Not Fraud", "Fraud"],
        zero_division=0
    )
)
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       0.97      0.93      0.95      1461
#        Fraud       0.02      0.05      0.03        39
#
#     accuracy                           0.91      1500
#    macro avg       0.50      0.49      0.49      1500
# weighted avg       0.95      0.91      0.93      1500

# %%
for name, model in models.items():

    y_pred = model.predict(X_test)

    print("\n==============================")
    print(name)
    print("==============================")

    print("Predictions:")
    print(pd.Series(y_pred).value_counts())

    print("\nActual:")
    print(y_test.value_counts())
# Out:
# ==============================
# Decision Tree
# ==============================
# Predictions:
# 0    1396
# 1     104
# Name: count, dtype: int64
#
# Actual:
# is_fraudulent
# 0    1461
# 1      39
# Name: count, dtype: int64
#
# ==============================
# Random Forest
# ==============================
# Predictions:
# 0    1497
# 1       3
# Name: count, dtype: int64
#
# Actual:
# is_fraudulent
# 0    1461
# 1      39
# Name: count, dtype: int64
#
# ==============================
# XGBoost
# ==============================
# Predictions:
# 0    1500
# Name: count, dtype: int64
#
# Actual:
# is_fraudulent
# 0    1461
# 1      39
# Name: count, dtype: int64

# %%
xgb_prob = xgb_pipeline.predict_proba(X_test)[:, 1]

print(xgb_prob.min())
print(xgb_prob.max())
print(xgb_prob.mean())
# Out:
# 0.00037138702
# 0.42823535
# 0.02613586

# %%
print(
    pd.DataFrame({
        "Actual": y_test.values,
        "Fraud_Probability": xgb_prob
    })
    .sort_values("Fraud_Probability", ascending=False)
    .head(30)
)
# Out:
#       Actual  Fraud_Probability
# 699        1           0.428235
# 1120       0           0.400801
# 1442       0           0.357956
# 1367       0           0.257159
# 1147       0           0.246013
# 776        1           0.232206
# 1498       0           0.230985
# 1300       0           0.216813
# 18         0           0.212483
# 505        0           0.200197
# 725        0           0.199228
# 201        0           0.195127
# 1101       0           0.183921
# 227        0           0.177449
# 717        0           0.176171
# 656        0           0.175392
# 470        0           0.172448
# 269        0           0.170599
# 432        0           0.165541
# 1179       0           0.161525
# 502        0           0.158777
# 1396       0           0.154474
# 1365       0           0.149157
# 967        0           0.144043
# 1344       0           0.143929
# 836        0           0.139878
# 45         0           0.138039
# 1092       0           0.135313
# 28         0           0.135074
# 1378       0           0.134008

# %%
dt_pred = dt_pipeline.predict(X_test)

cm = confusion_matrix(y_test, dt_pred)

print(cm)

print(
    classification_report(
        y_test,
        dt_pred,
        target_names=["Not Fraud", "Fraud"],
        zero_division=0
    )
)
# Out:
# [[1359  102]
#  [  37    2]]
#               precision    recall  f1-score   support
#
#    Not Fraud       0.97      0.93      0.95      1461
#        Fraud       0.02      0.05      0.03        39
#
#     accuracy                           0.91      1500
#    macro avg       0.50      0.49      0.49      1500
# weighted avg       0.95      0.91      0.93      1500

# %%
for name, model in models.items():

    y_pred = model.predict(X_test)

    print("\n" + "=" * 50)
    print(name)
    print("=" * 50)

    print(
        classification_report(
            y_test,
            y_pred,
            target_names=["Not Fraud", "Fraud"],
            zero_division=0
        )
    )

    print("Confusion Matrix:")
    print(confusion_matrix(y_test, y_pred))
# Out:
# ==================================================
# Decision Tree
# ==================================================
#               precision    recall  f1-score   support
#
#    Not Fraud       0.97      0.93      0.95      1461
#        Fraud       0.02      0.05      0.03        39
#
#     accuracy                           0.91      1500
#    macro avg       0.50      0.49      0.49      1500
# weighted avg       0.95      0.91      0.93      1500
#
# Confusion Matrix:
# [[1359  102]
#  [  37    2]]
#
# ==================================================
# Random Forest
# ==================================================
#               precision    recall  f1-score   support
#
#    Not Fraud       0.97      1.00      0.99      1461
#        Fraud       0.00      0.00      0.00        39
#
#     accuracy                           0.97      1500
#    macro avg       0.49      0.50      0.49      1500
# weighted avg       0.95      0.97      0.96      1500
#
# Confusion Matrix:
# [[1458    3]
#  [  39    0]]
#
# ==================================================
# XGBoost
# ==================================================
#               precision    recall  f1-score   support
#
#    Not Fraud       0.97      1.00      0.99      1461
#        Fraud       0.00      0.00      0.00        39
#
#     accuracy                           0.97      1500
#    macro avg       0.49      0.50      0.49      1500
# weighted avg       0.95      0.97      0.96      1500
#
# Confusion Matrix:
# [[1461    0]
#  [  39    0]]

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

for threshold in [0.30, 0.20, 0.15, 0.10, 0.05, 0.03, 0.02, 0.01]:

    y_pred = (xgb_prob >= threshold).astype(int)

    print(
        f"Threshold={threshold:.2f} | "
        f"Precision={precision_score(y_test, y_pred, zero_division=0):.3f} | "
        f"Recall={recall_score(y_test, y_pred, zero_division=0):.3f} | "
        f"F1={f1_score(y_test, y_pred, zero_division=0):.3f}"
    )
# Out:
# Threshold=0.30 | Precision=0.333 | Recall=0.026 | F1=0.048
# Threshold=0.20 | Precision=0.200 | Recall=0.051 | F1=0.082
# Threshold=0.15 | Precision=0.091 | Recall=0.051 | F1=0.066
# Threshold=0.10 | Precision=0.055 | Recall=0.077 | F1=0.064
# Threshold=0.05 | Precision=0.046 | Recall=0.256 | F1=0.078
# Threshold=0.03 | Precision=0.035 | Recall=0.359 | F1=0.064
# Threshold=0.02 | Precision=0.037 | Recall=0.538 | F1=0.070
# Threshold=0.01 | Precision=0.033 | Recall=0.769 | F1=0.062
